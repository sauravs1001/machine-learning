# %% [markdown]
# ### Creating Pandas DataFrame

# %%
import pandas as pd

# %% [markdown]
#  To read csv file and store it as a pandas dataframe
#  Other pandas read file methods are:
#
# - pd.read_excel()
# - pd.read_html()
# - pd.read_json()
# - pd.read_sql()
# - pd.read_table

# %%
# importing titanic.csv file as a dataframe and storing the datframe in titanic variable

titanic = pd.read_csv("titanic.csv")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# titanic.iloc[:10, :-2].values
type(titanic.iloc[:10, :-2].values)
# Out:
# numpy.ndarray

# %% [markdown]
# ### Pandas Display Options and the methods head() & tail()

# %%
titanic  # This way it will display first 5 rows and last 5 rows of the dataframe
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %%
# print()function does not work well while displaying pandas dataframe.
# Style of display is not nice through print() function
# Less readable & Poorly formatted text based output

print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 886         0       2    male  27.0      0      0  13.0000        S  NaN
# 887         1       1  female  19.0      0      0  30.0000        S    B
# 888         0       3  female   NaN      1      2  23.4500        S  NaN
# 889         1       1    male  26.0      0      0  30.0000        C    C
# 890         0       3    male  32.0      0      0   7.7500        Q  NaN
#
# [891 rows x 9 columns]

# %% [markdown]
# ----------------------------------------------------------------
#
#
#
# - **By default Pandas will display first 5 rows and lat 5 rows of a Dataframe, and the reason is, there are some standard or default display settings which we can see by running the below commands.**
#
#
# - **so if the dataframe has equal or less rows than the max rows setting, then by default Pandas will display all the rows of the dataframe.**
#
#
# - **But if the dataframe has more rows than the max_rows setting, in that case the min_rows settings will be considered.**
#
#
# - **In most of the cases the number of rows in a dataframe has more than 60 rows of data which is the default max_rows settings, so that's why we only see 10 rows of data (first 5 rows and last 5 rows) as per the default min_rows settings**
#
#
# -------------------------------------------------------------------

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.options.display.min_rows
# Out:
# 10

# %% [markdown]
# **We can also change the max_rows and min_rows settings by assigning them with new values
# for example-->
# pd.options.display.max_rows = 900**
#
# **In that case we will be able to see all the 891 rows of titanic dataframe**

# %%
# To see the first 10 rows and last 10 rows of titanic dataframe

pd.options.display.min_rows = 20

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# ...

# %% [markdown]
# -----------------------------------------------------------
# -----------------------------------------------------------
# we could also print or output all rows of a dataframe. So of course this doesn't make sense if the data frame has thousands or even millions of rows. But in our example we have 891 rows.
#
# This is still feasible and could make sense. And the only thing we have to do is actually we have to set max_rows setting to a number that is equal or higher than the total number of rows in our data frame.
#
# So in our case at least 891.And let's again print Titanic and we can now scroll down and to we could actually analyse and observe all 891 rows of our data frame.
#
# --------------------------------------------------------------------
# --------------------------------------------------------------------

# %%
# pd.options.display.max_rows = 900

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# ...

# %%
# By default head() method displays first 5 rows of the DataFrame, but we can also pass a number to the head() method and get our required number of rows

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
titanic.head(20) # OR titanic.head(n=20)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.tail()
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked deck
# 886         0       2    male  27.0      0      0  13.00        S  NaN
# 887         1       1  female  19.0      0      0  30.00        S    B
# 888         0       3  female   NaN      1      2  23.45        S  NaN
# 889         1       1    male  26.0      0      0  30.00        C    C
# 890         0       3    male  32.0      0      0   7.75        Q  NaN

# %%
titanic.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked deck
# 889         1       1  male  26.0      0      0  30.00        C    C
# 890         0       3  male  32.0      0      0   7.75        Q  NaN

# %% [markdown]
# # First Data Inspection

# %% [markdown]
# ---
# ---
# typically when working with data and with new datasets we don't know much about the data.
#
# And before we can start with our primary task and this can be explanatory data analysis, data visualization, statistical analysis machine learning or whatever.
#
# So before we can start with this we need to perform a very first inspection and based on that first inspection we can plan the next steps.
#
# For instance we could come to the conclusion that we need additional data or that we need to clean the data or transform the data or handle missing values or whatever.
#
# And it is very often the case that this first inspection is underestimated.
# However coming from the business side I have to emphasize that understanding our data and understanding your task is the key to success.
#
# ---
# ---

# %% [markdown]
# ---
# ---
#
# Note:
# - Range Index --> Range index is simply a consecutive numbers of the rows.
# - In titanic dataframe, we have 891 rows or 891 observations.
# - Each row is for one passenger on board of the Titanic.
# - We have 9 columns in the DataFrame and each column is a characteristic or feature of the perticular passenger.
# - Typically when importing data from a csv file, a range index gets vreated by default.
# - From each column we can know the data type, such as integer or float or String Object etc
#
# ---
# ---

# %% [markdown]
# Note:
# - NaN stands for not a number.
# - it indicates missing values in a DataFrame
# - Missing values in a DataFrame are very common and Pandas designed to handle missing values.

# %%
# info() methos is a very important method for First Data inspection.
# It summarizes the dataframe info and shows important meta information at a glance.

titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %% [markdown]
# ---
# ---
#
# So this is a very small dataset with 62.8 kilobytes but of course there could also have a data frame or datasets with megabytes or even gigabytes.
#
# So again the info() method is really useful and helpful and actually the functionality and the behavior of a data frame is determined by only a few things.
#
# It's the index --> so a Range Index behaves different than a datetime index with datetime information.
# And second we have the columns and the data types of the columns.
# And last but not least also the missing values (NaN)
#
# So these factors actually determine the functionality of our data frame and we can see those factors at a glance by calling the df.info() method.
#
# ---
# ---

# %%
# describe() method by default returms statistical summary of numerical columns of the DataFrame

# Count --> Number of non missing values
# mean --> Average
# std --> Standard Deviation
# min --> The minimum value available in the specific column
# 25% --> the 25th percentile or 1st quartile
# 50% --> The 50th percentile or Median of the data ( specific Column data set)
# 75% --> the 75th percentile or 3rd quartile
# max --> The maximum value available in the specific column

titanic.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Through describe() method we can also analyze non-numerical columns data as follows:

titanic.describe(include='O')  # Include Object columns
# Out:
#          sex embarked deck
# count    891      889  203
# unique     2        3    7
# top     male        S    C
# freq     577      644   59

# %% [markdown]
# ### Python Built-in Functions & DataFrame Attributes and Methods

# %%
# To check the datatype of any object we use type() function.
# So here titanic is a dataframe object or we can also say this object is an instance of the class Pandas DataFrame
# In Python functionality of an object depends on the attributes and methods that are defined for the class that the Object belongs to.

# %%
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# the PANDAS data frame has dozens of methods and over 1000 developers have worked for years
# on it to create and improve the functionality of pandas and as a result the pandas is and will be the
# most powerful data handling and data analysis tool in Python.

# %%
# Some more Python built-in functions.

len(titanic) # Returns the length of an object. len('TEST') --> 4
             # Here len() function returns the number of rows in the DataFrame.
# Out:
# 891

# %%
# round() function --> round all elemnets in numerical columns to 'x' digits or decimals depending on the value of 'x'

round(titanic, 0)
# Out:
#      survived  pclass     sex   age  sibsp  parch  fare embarked deck
# 0           0       3    male  22.0      1      0   7.0        S  NaN
# 1           1       1  female  38.0      1      0  71.0        C    C
# 2           1       3  female  26.0      0      0   8.0        S  NaN
# 3           1       1  female  35.0      1      0  53.0        S    C
# 4           0       3    male  35.0      0      0   8.0        S  NaN
# 5           0       3    male   NaN      0      0   8.0        Q  NaN
# 6           0       1    male  54.0      0      0  52.0        S    E
# 7           0       3    male   2.0      3      1  21.0        S  NaN
# 8           1       3  female  27.0      0      2  11.0        S  NaN
# 9           1       2  female  14.0      1      0  30.0        C  NaN
# ..        ...     ...     ...   ...    ...    ...   ...      ...  ...
# 881         0       3    male  33.0      0      0   8.0        S  NaN
# ...

# %%
int(titanic)  # To convert the DataFrame object to ian integer, will give error as it's not supported
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-107-e4e2acf20618> in <module>
# ----> 1 int(titanic)  # To convert the DataFrame object to ian integer, will give error as it's not supported
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'DataFrame'

# %%
# Python min() function to get the minimum value but here we get the minimum column label or column name sorted alphabetically

min(titanic)
# Out:
# 'age'

# %% [markdown]
# ---
# As per above examples, the functionality of Python built-in functions is limited for Pandas DataFrame objects, that's why we should use the Pandas methods and attributes that are specifically created for Pandas Objects.
#
# ---

# %% [markdown]
# ### DataFrame Attributes

# %% [markdown]
# - An attribute is a feature or a characteristic of an object that is already stored in the object.
#
# - df.shape  --> returns the shape of dataframe object, that is number of rows and number of columns of the dataframe
# - df.size --> Total number of elements in the dataframe, no. of rows * no. of columns
# - df.index --> Returns the index of the dataframe, Might be range index or label index
# - df.columns --> Returns all the column names or column labels of the DataFrame object

# %%
titanic.shape
# Out:
# (891, 9)

# %%
titanic.size
# Out:
# 8019

# %%
titanic.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'deck'],
#       dtype='object')

# %% [markdown]
# ### DataFrame Methods

# %% [markdown]
# - A method is like a function but specifically designed for that object or the class
# - We can pass parameters in the method to customize the method return value
# - head() method - Outputs first 5 rows of the dataframe by default
# - info() method - returns summary info on the dataframe object
# - min() method - Returns the minimum value of ech column in the dataframe
# - max() method - Returns the maximum value of each column in the DataFrame
# - **Refer Pandas documentation for various methodsand Attributes**
#
# [Pandas Official Documentation Page](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %%
titanic.head(n = 13)
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0          0       3    male  22.0      1      0   7.2500        S  NaN
# 1          1       1  female  38.0      1      0  71.2833        C    C
# 2          1       3  female  26.0      0      0   7.9250        S  NaN
# 3          1       1  female  35.0      1      0  53.1000        S    C
# 4          0       3    male  35.0      0      0   8.0500        S  NaN
# 5          0       3    male   NaN      0      0   8.4583        Q  NaN
# 6          0       1    male  54.0      0      0  51.8625        S    E
# 7          0       3    male   2.0      3      1  21.0750        S  NaN
# 8          1       3  female  27.0      0      2  11.1333        S  NaN
# 9          1       2  female  14.0      1      0  30.0708        C  NaN
# 10         1       3  female   4.0      1      1  16.7000        S    G
# 11         1       1  female  58.0      0      0  26.5500        S    C
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   sex       891 non-null    object
#  3   age       714 non-null    float64
#  4   sibsp     891 non-null    int64
#  5   parch     891 non-null    int64
#  6   fare      891 non-null    float64
#  7   embarked  889 non-null    object
#  8   deck      203 non-null    object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 62.8+ KB

# %%
titanic.min()
# Out:
# survived         0
# pclass           1
# sex         female
# age           0.42
# sibsp            0
# parch            0
# fare             0
# dtype: object

# %%
titanic.max()
# Out:
# survived          1
# pclass            3
# sex            male
# age              80
# sibsp             8
# parch             6
# fare        512.329
# dtype: object

# %%
titanic.mean() # Returns average value of each column data set
# Out:
# survived     0.383838
# pclass       2.308642
# age         29.699118
# sibsp        0.523008
# parch        0.381594
# fare        32.204208
# dtype: float64

# %% [markdown]
# ### Method Chaining
#
# let's have a simple example here. So first of all let's try to calculate the mean value in all columns and we can actually do this with the mean() method, so here we have the mean values in our columns and for instance the the survival rate is 38.3% and we can also sort of those values from high to low or from low to high and we can simply chain another method.
# That's the sort values method and let's call the method and the by default the sort_values() method sort all elements from low to high so we're starting with the lowest mean in the parents and children column
# lowest to the highest mean value in the Fair column. And finally we can also only have a look at the the first two elements and the it's no surprise that we can chain here the head() method and we can pass 2 to get to the first two elements.
#
# And again this concept is called Method chaining as we chain the methods one after another.

# %%
# titanic.mean()
# titanic.mean().sort_values()

titanic.mean().sort_values().head(2)
# Out:
# parch       0.381594
# survived    0.383838
# dtype: float64

# %% [markdown]
# ## Selecting one or many Columns in Pandas DataFrame

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0           0       3    male  22.0      1      0   7.2500        S  NaN
# 1           1       1  female  38.0      1      0  71.2833        C    C
# 2           1       3  female  26.0      0      0   7.9250        S  NaN
# 3           1       1  female  35.0      1      0  53.1000        S    C
# 4           0       3    male  35.0      0      0   8.0500        S  NaN
# 5           0       3    male   NaN      0      0   8.4583        Q  NaN
# 6           0       1    male  54.0      0      0  51.8625        S    E
# 7           0       3    male   2.0      3      1  21.0750        S  NaN
# 8           1       3  female  27.0      0      2  11.1333        S  NaN
# 9           1       2  female  14.0      1      0  30.0708        C  NaN
# ..        ...     ...     ...   ...    ...    ...      ...      ...  ...
# 881         0       3    male  33.0      0      0   7.8958        S  NaN
# ...

# %%
# Like Python lists, strings, numpy arrays, we can also index Pandas objects
# To select a column we can pass the column name in the square bracket within double quotes

titanic["age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
#        ...
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %% [markdown]
# ---
# - The output in above example is a column of titanic DataFrame, but it's also is a Pandas Series.
# - A Pandas Series is very similar to a DataFrame but it's 1-dimensional. It has only one column.
# - Series object is also called as one dimensional labelled array. it's called labeled because we have the index in the left side
#
# ---

# %%
type(titanic["age"])
# Out:
# pandas.core.series.Series

# %%
# To select 2 or many columns we have to pass the column names or column labels as a list object
# If we select 2 or more columns, the output will be a Pandas dataframe.

titanic[["age", "sex", "fare"]]
# Out:
#       age     sex     fare
# 0    22.0    male   7.2500
# 1    38.0  female  71.2833
# 2    26.0  female   7.9250
# 3    35.0  female  53.1000
# 4    35.0    male   8.0500
# 5     NaN    male   8.4583
# 6    54.0    male  51.8625
# 7     2.0    male  21.0750
# 8    27.0  female  11.1333
# 9    14.0  female  30.0708
# ..    ...     ...      ...
# 881  33.0    male   7.8958
# 882  22.0  female  10.5167
# 883  28.0    male  10.5000
# 884  25.0    male   7.0500
# 885  39.0  female  29.1250
# 886  27.0    male  13.0000
# 887  19.0  female  30.0000
# 888   NaN  female  23.4500
# 889  26.0    male  30.0000
# 890  32.0    male   7.7500
#
# [891 rows x 3 columns]

# %%
type(titanic[["age", "sex", "fare"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# We can also change the sequence of the columns while displaying multiple columns

titanic[["sex", "fare", "age"]]
# Out:
#         sex     fare   age
# 0      male   7.2500  22.0
# 1    female  71.2833  38.0
# 2    female   7.9250  26.0
# 3    female  53.1000  35.0
# 4      male   8.0500  35.0
# 5      male   8.4583   NaN
# 6      male  51.8625  54.0
# 7      male  21.0750   2.0
# 8    female  11.1333  27.0
# 9    female  30.0708  14.0
# ..      ...      ...   ...
# 881    male   7.8958  33.0
# 882  female  10.5167  22.0
# 883    male  10.5000  28.0
# 884    male   7.0500  25.0
# 885  female  29.1250  39.0
# 886    male  13.0000  27.0
# 887  female  30.0000  19.0
# 888  female  23.4500   NaN
# 889    male  30.0000  26.0
# 890    male   7.7500  32.0
#
# [891 rows x 3 columns]

# %%
# If we pass one column label as a list then the output will be a Dataframe, not a Series

titanic[["age"]]
# Out:
#       age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# 5     NaN
# 6    54.0
# 7     2.0
# 8    27.0
# 9    14.0
# ..    ...
# 881  33.0
# 882  22.0
# 883  28.0
# 884  25.0
# 885  39.0
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]

# %%
type(titanic[["age"]])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Note:
# - Pandas Series and Pandas DataFrame objects share most of the methods. there is only very few different methods for both type of objects

# %% [markdown]
# ### Selecting one Column with "dot notation"

# %%
# we can also use the dot notation or attribute notation to select one column from a DataFrame
# dot notation will not work when the column label contains whitespaces

titanic.age
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 5       NaN
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
#        ...
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
# when selecting one column the dot notation and these square brackets annotation 
# are equivalent and lead to to the same output.

titanic.age.equals(titanic["age"])  # equals() method tests whether two objects contain same elements
# Out:
# True

# %%
# In case of dot notation we can use the Tab key to autocomplete the column labels

titanic.embarked
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
# 5      Q
# 6      S
# 7      S
# 8      S
# 9      C
#       ..
# 881    S
# 882    S
# 883    S
# 884    S
# 885    Q
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: embarked, Length: 891, dtype: object

# %% [markdown]
# ### Zero based Indexing and Negative Indexing

# %% [markdown]
# ![zero_based_indexing.png](attachment:zero_based_indexing.png)

# %% [markdown]
# ![negative_indexing.png](attachment:negative_indexing.png)

# %%
# Pandas DataFrame is a 2-dimensional object having rows and columns, therefore we need index positions for rows and also for columns

# %% [markdown]
# ### Position-based Indexing and Slicing with .iloc operator

# %%
import pandas as pd

# %%
summer = pd.read_csv("summer.csv")

# %%
summer
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31155  2012  London  Wrestling  Wrestling Freestyle
# 31156  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31158  2012  London  Wrestling  Wrestling Freestyle
# 31159  2012  London  Wrestling  Wrestling Freestyle
# 31160  2012  London  Wrestling  Wrestling Freestyle
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31165 entries, 0 to 31164
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Athlete     31165 non-null  object
#  5   Country     31161 non-null  object
#  6   Gender      31165 non-null  object
#  7   Event       31165 non-null  object
#  8   Medal       31165 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 2.1+ MB

# %%
# We can also change the default index of a DataFrame while importing the csv file.
# We can set any column as index of the DataFrame

summer = pd.read_csv("summer.csv", index_col="Athlete")

# %%
summer
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto              1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios             1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# NEUMANN, Paul                 1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# ...

# %%
# Now if we run the info method on the summer dataframe object, we will see the index information changed
# Range index changed to Labelled index

summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31165 entries, HAJOS, Alfred to LIDBERG, Jimmy
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        31165 non-null  int64
#  1   City        31165 non-null  object
#  2   Sport       31165 non-null  object
#  3   Discipline  31165 non-null  object
#  4   Country     31161 non-null  object
#  5   Gender      31165 non-null  object
#  6   Event       31165 non-null  object
#  7   Medal       31165 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 2.1+ MB

# %% [markdown]
# #### Selecting Rows with iloc[]

# %%
# To select very first row of the summer DataFrame

summer.iloc[0]    # Here the index will be various column names
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  HUN
# Gender                   Men
# Event         100M Freestyle
# Medal                   Gold
# Name: HAJOS, Alfred, dtype: object

# %%
type(summer.iloc[0]) # Whenever the output is one row or one column in Pandas, it's a series object
# Out:
# pandas.core.series.Series

# %%
summer.iloc[1]
# Out:
# Year                    1896
# City                  Athens
# Sport               Aquatics
# Discipline          Swimming
# Country                  AUT
# Gender                   Men
# Event         100M Freestyle
# Medal                 Silver
# Name: HERSCHMANN, Otto, dtype: object

# %%
# To get the very last row of the DataFrame

summer.iloc[-1]
# Out:
# Year                         2012
# City                       London
# Sport                   Wrestling
# Discipline    Wrestling Freestyle
# Country                       SWE
# Gender                        Men
# Event                    Wg 96 KG
# Medal                      Bronze
# Name: LIDBERG, Jimmy, dtype: object

# %%
# To get the rows at index positions 1,2 & 3

summer.iloc[[1,2,3]]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
# Better Solution to slice 

summer.iloc[1:4]  # Position 1 inclusive & position 4 exclusive
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold

# %%
# To get the first 5 rows

summer.iloc[0:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
# There is another more efficient way to output first 5 rows

summer.iloc[:5]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %%
# To get last 5 rows

summer.iloc[-5:]
# Out:
#                            Year    City      Sport           Discipline  \
# Athlete
# JANIKOWSKI, Damian         2012  London  Wrestling  Wrestling Freestyle
# REZAEI, Ghasem Gholamreza  2012  London  Wrestling  Wrestling Freestyle
# TOTROV, Rustam             2012  London  Wrestling  Wrestling Freestyle
# ALEKSANYAN, Artur          2012  London  Wrestling  Wrestling Freestyle
# LIDBERG, Jimmy             2012  London  Wrestling  Wrestling Freestyle
#
#                           Country Gender     Event   Medal
# Athlete
# JANIKOWSKI, Damian            POL    Men  Wg 84 KG  Bronze
# REZAEI, Ghasem Gholamreza     IRI    Men  Wg 96 KG    Gold
# TOTROV, Rustam                RUS    Men  Wg 96 KG  Silver
# ALEKSANYAN, Artur             ARM    Men  Wg 96 KG  Bronze
# LIDBERG, Jimmy                SWE    Men  Wg 96 KG  Bronze

# %%
# To get all the rows in summer dataframe using .iloc operator

summer.iloc[:] # or we can simply print summer dataframe
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto              1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios             1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# NEUMANN, Paul                 1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# ...

# %%
# Also we can pass some index positions as per our requirement and those indexes need not be continuous

summer.iloc[[2, 45, 78, 102, 5467]]
# Out:
#                    Year       City       Sport   Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios  1896     Athens    Aquatics     Swimming     GRE    Men
# PERSAKIS, Ioannis  1896     Athens   Athletics    Athletics     GRE    Men
# PERSAKIS, Petros   1896     Athens  Gymnastics  Artistic G.     GRE    Men
# HILMAR, Georg      1896     Athens  Gymnastics  Artistic G.     GER    Men
# POLAK, Ans         1928  Amsterdam  Gymnastics  Artistic G.     NED  Women
#
#                                         Event   Medal
# Athlete
# DRIVAS, Dimitrios  100M Freestyle For Sailors  Bronze
# PERSAKIS, Ioannis                 Triple Jump  Bronze
# PERSAKIS, Petros                        Rings  Bronze
# HILMAR, Georg             Team, Parallel Bars    Gold
# POLAK, Ans                   Team Competition    Gold

# %% [markdown]
# ### Indexing/Slicing Rows and Columns with .iloc operator

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %%
# To Select Country as 'HUN' from the first row of the summer dataframe

summer.iloc[0, 4] # The left hand side of the comma is for rows and right hand side of the comma is for column index
# Out:
# 'HUN'

# %%
# To get the first row and first 3 columns of summer dataframe 

summer.iloc[0, :3]
# Out:
# Year         1896
# City       Athens
# Sport    Aquatics
# Name: HAJOS, Alfred, dtype: object

# %%
# More complex operations example

summer.iloc[0, [0, 2, 5, 7]]  # First row and required columns
# Out:
# Year          1896
# Sport     Aquatics
# Gender         Men
# Medal         Gold
# Name: HAJOS, Alfred, dtype: object

# %%
# More complex

summer.iloc[34:39, [0, 2, 5, 7]]
# Out:
#                       Year      Sport Gender   Medal
# Athlete
# GARRETT, Robert       1896  Athletics    Men  Silver
# KELLNER, Gyula        1896  Athletics    Men  Bronze
# LOUIS, Spyridon       1896  Athletics    Men    Gold
# VASILAKOS, Kharilaos  1896  Athletics    Men  Silver
# DAMASKOS, Evangelos   1896  Athletics    Men  Bronze

# %%
# To select all rows with one columns using iloc. here we are selecting country column and all rows

summer.iloc[: , 4]
# Out:
# Athlete
# HAJOS, Alfred                   HUN
# HERSCHMANN, Otto                AUT
# DRIVAS, Dimitrios               GRE
# MALOKINIS, Ioannis              GRE
# CHASAPIS, Spiridon              GRE
# CHOROPHAS, Efstathios           GRE
# HAJOS, Alfred                   HUN
# ANDREOU, Joannis                GRE
# CHOROPHAS, Efstathios           GRE
# NEUMANN, Paul                   AUT
#                                ...
# AHMADOV, Emin                   AZE
# KAZAKEVIC, Aleksandr            LTU
# KHUGAEV, Alan                   RUS
# EBRAHIM, Karam Mohamed Gaber    EGY
# GAJIYEV, Danyal                 KAZ
# JANIKOWSKI, Damian              POL
# REZAEI, Ghasem Gholamreza       IRI
# TOTROV, Rustam                  RUS
# ALEKSANYAN, Artur               ARM
# LIDBERG, Jimmy                  SWE
# Name: Country, Length: 31165, dtype: object

# %% [markdown]
# - **Other alternatives to select 1 column and all the rows are summer["Country"] or summer.Country**
#
# - **All the alternatives deliver same output and we can check that with equals() method**

# %%
summer.iloc[: , 4].equals(summer.Country)
# Out:
# True

# %%
summer.iloc[: , 4].equals(summer["Country"])
# Out:
# True

# %% [markdown]
# ### Label-based Indexing and Slicing with .loc operator

# %%
summer
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto              1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios             1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# NEUMANN, Paul                 1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# ...

# %%
# To select the 3rd row of the dataframe

summer.iloc[2]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
# But if we don't know the row index number and want to search for athlete name by passing the name as index we need to use .loc operator

summer.loc["DRIVAS, Dimitrios"]
# Out:
# Year                                1896
# City                              Athens
# Sport                           Aquatics
# Discipline                      Swimming
# Country                              GRE
# Gender                               Men
# Event         100M Freestyle For Sailors
# Medal                             Bronze
# Name: DRIVAS, Dimitrios, dtype: object

# %%
# To get all the rows for Michael Phelps, so that we can get all his medal information

summer.loc["PHELPS, Michael"] # This operation cannot be done using .iloc operator as we don't know the index position numbers for all the medal info rows
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
# So now we can store the slice information in a variable and do further analysis

mphelps = summer.loc["PHELPS, Michael"]

# %%
mphelps
# Out:
#                  Year     City     Sport Discipline Country Gender  \
# Athlete
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2004   Athens  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# PHELPS, Michael  2008  Beijing  Aquatics   Swimming     USA    Men
# ...

# %%
type(mphelps)
# Out:
# pandas.core.frame.DataFrame

# %%
mphelps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, PHELPS, Michael to PHELPS, Michael
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        22 non-null     int64
#  1   City        22 non-null     object
#  2   Sport       22 non-null     object
#  3   Discipline  22 non-null     object
#  4   Country     22 non-null     object
#  5   Gender      22 non-null     object
#  6   Event       22 non-null     object
#  7   Medal       22 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 1.5+ KB

# %%
mphelps.loc[:, ["Year", "Event", "Medal"]] # to get the Year info,event info and respective medal info
# Out:
#                  Year                   Event   Medal
# Athlete
# PHELPS, Michael  2004          100M Butterfly    Gold
# PHELPS, Michael  2004          200M Butterfly    Gold
# PHELPS, Michael  2004          200M Freestyle  Bronze
# PHELPS, Michael  2004  200M Individual Medley    Gold
# PHELPS, Michael  2004  400M Individual Medley    Gold
# PHELPS, Michael  2004  4X100M Freestyle Relay  Bronze
# PHELPS, Michael  2004     4X100M Medley Relay    Gold
# PHELPS, Michael  2004  4X200M Freestyle Relay    Gold
# PHELPS, Michael  2008          100M Butterfly    Gold
# PHELPS, Michael  2008          200M Butterfly    Gold
# PHELPS, Michael  2008          200M Freestyle    Gold
# PHELPS, Michael  2008  200M Individual Medley    Gold
# PHELPS, Michael  2008  400M Individual Medley    Gold
# PHELPS, Michael  2008  4X100M Freestyle Relay    Gold
# PHELPS, Michael  2008     4X100M Medley Relay    Gold
# PHELPS, Michael  2008  4X200M Freestyle Relay    Gold
# ...

# %% [markdown]
# ### Indexing/Slicing Rows and Columns with loc operator

# %%
# To display all the medals of Michael Phelps
summer.loc["PHELPS, Michael", "Medal"]
# Out:
# Athlete
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Bronze
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael    Silver
# PHELPS, Michael      Gold
# PHELPS, Michael      Gold
# Name: Medal, dtype: object

# %%
# To get more than 1 column we can simply pass a list of column names on the right hand side of comma

summer.loc["PHELPS, Michael", ["Event", "Medal"]]
# Out:
#                                   Event   Medal
# Athlete
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle  Bronze
# PHELPS, Michael  200M Individual Medley    Gold
# PHELPS, Michael  400M Individual Medley    Gold
# PHELPS, Michael  4X100M Freestyle Relay  Bronze
# PHELPS, Michael     4X100M Medley Relay    Gold
# PHELPS, Michael  4X200M Freestyle Relay    Gold
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle    Gold
# PHELPS, Michael  200M Individual Medley    Gold
# PHELPS, Michael  400M Individual Medley    Gold
# PHELPS, Michael  4X100M Freestyle Relay    Gold
# PHELPS, Michael     4X100M Medley Relay    Gold
# PHELPS, Michael  4X200M Freestyle Relay    Gold
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly  Silver
# ...

# %%
# We can also make more complex information on the left side of the comma
# To display the medals won by Carl Lewis and Michael Phelps

summer.loc[["PHELPS, Michael", "LEWIS, Carl"], ["Event", "Medal"]]
# Out:
#                                   Event   Medal
# Athlete
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle  Bronze
# PHELPS, Michael  200M Individual Medley    Gold
# PHELPS, Michael  400M Individual Medley    Gold
# PHELPS, Michael  4X100M Freestyle Relay  Bronze
# PHELPS, Michael     4X100M Medley Relay    Gold
# PHELPS, Michael  4X200M Freestyle Relay    Gold
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly    Gold
# PHELPS, Michael          200M Freestyle    Gold
# PHELPS, Michael  200M Individual Medley    Gold
# PHELPS, Michael  400M Individual Medley    Gold
# PHELPS, Michael  4X100M Freestyle Relay    Gold
# PHELPS, Michael     4X100M Medley Relay    Gold
# PHELPS, Michael  4X200M Freestyle Relay    Gold
# PHELPS, Michael          100M Butterfly    Gold
# PHELPS, Michael          200M Butterfly  Silver
# ...

# %%
# To select all the rows and required columns with the .loc operator

summer.loc[: , ["Event", "Medal"]]
# Out:
#                                                    Event   Medal
# Athlete
# HAJOS, Alfred                             100M Freestyle    Gold
# HERSCHMANN, Otto                          100M Freestyle  Silver
# DRIVAS, Dimitrios             100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis            100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon            100M Freestyle For Sailors  Silver
# CHOROPHAS, Efstathios                    1200M Freestyle  Bronze
# HAJOS, Alfred                            1200M Freestyle    Gold
# ANDREOU, Joannis                         1200M Freestyle  Silver
# CHOROPHAS, Efstathios                     400M Freestyle  Bronze
# NEUMANN, Paul                             400M Freestyle    Gold
# ...                                                  ...     ...
# AHMADOV, Emin                                   Wg 74 KG  Bronze
# KAZAKEVIC, Aleksandr                            Wg 74 KG  Bronze
# ...

# %%
summer.head(10)
# Out:
#                        Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens  Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens  Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens  Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens  Aquatics   Swimming     AUT    Men
#
#                                             Event   Medal
# Athlete
# HAJOS, Alfred                      100M Freestyle    Gold
# ...

# %% [markdown]
# Note:
# - We can also perform slicing so from two and actually labeled by slicing with text data on the indexes is not the most relevant case and practice. So there is hardly any reason why you should slice from Michael Phelps to Carl Lewis. But this is a good example to show you some pitfalls when slicing an index of duplicate entries and in practice a label by slicing is heavily used with the date time data on the index a so-called date and time index and you will see this in later sections of this course. But for the time being let's assume that we want to get all rows from the very beginning to including the row with Spiridon CHASAPIS athlete. And actually this is pretty straight forward with the loc operator

# %%
# To display all the record from beginning till "CHASAPIS, Spiridon" athlete

summer.loc[:"CHASAPIS, Spiridon"]
# Out:
#                     Year    City     Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred       1896  Athens  Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto    1896  Athens  Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios   1896  Athens  Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis  1896  Athens  Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon  1896  Athens  Aquatics   Swimming     GRE    Men
#
#                                          Event   Medal
# Athlete
# HAJOS, Alfred                   100M Freestyle    Gold
# HERSCHMANN, Otto                100M Freestyle  Silver
# DRIVAS, Dimitrios   100M Freestyle For Sailors  Bronze
# MALOKINIS, Ioannis  100M Freestyle For Sailors    Gold
# CHASAPIS, Spiridon  100M Freestyle For Sailors  Silver

# %% [markdown]
# Note:
# - It's important to know the difference between iloc operator and loc operator
# - In iloc operator the left boundary is included the right boundary is excluded
# - In loc operator both the left and right boundaries are included

# %%
# To display all the record from beginning till "PHELPS, Michael" athlete

summer.loc[:"PHELPS, Michael"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-106-9168172b0b92> in <module>
#       1 # To display all the record from beginning till "PHELPS, Michael" athlete
#       2
# ----> 3 summer.loc[:"PHELPS, Michael"]
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1086         if isinstance(key, slice):
#    1087             self._validate_key(key, axis)
# -> 1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# ...

# %% [markdown]
# Note:
# - In the above example PHELPS, Michael record is a duplicate on our index therefore we cannot perform slicing operations

# %%
# We will also get the same error message if we try to slice from "PHELPS, Michael" till last row

summer.loc["PHELPS, Michael": ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-68b2372abdd2> in <module>
#       1 # We will also get the same error message if we try to slice from "PHELPS, Michael" till last row
#       2
# ----> 3 summer.loc["PHELPS, Michael": ]
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1086         if isinstance(key, slice):
#    1087             self._validate_key(key, axis)
# -> 1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
# ...

# %%
# Let's look at first 20 rows of the dataframe

summer.head(20)
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# HERSCHMANN, Otto       1896  Athens   Aquatics   Swimming     AUT    Men
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
# If Labels are unique then we can slice information from a dataframe using loc operator and labelled index

summer.loc["DRIVAS, Dimitrios":"BLAKE, Arthur"] # Both boundaries are included in loc operator
# Out:
#                        Year    City      Sport Discipline Country Gender  \
# Athlete
# DRIVAS, Dimitrios      1896  Athens   Aquatics   Swimming     GRE    Men
# MALOKINIS, Ioannis     1896  Athens   Aquatics   Swimming     GRE    Men
# CHASAPIS, Spiridon     1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# HAJOS, Alfred          1896  Athens   Aquatics   Swimming     HUN    Men
# ANDREOU, Joannis       1896  Athens   Aquatics   Swimming     GRE    Men
# CHOROPHAS, Efstathios  1896  Athens   Aquatics   Swimming     GRE    Men
# NEUMANN, Paul          1896  Athens   Aquatics   Swimming     AUT    Men
# PEPANOS, Antonios      1896  Athens   Aquatics   Swimming     GRE    Men
# LANE, Francis          1896  Athens  Athletics  Athletics     USA    Men
# SZOKOLYI, Alajos       1896  Athens  Athletics  Athletics     HUN    Men
# BURKE, Thomas          1896  Athens  Athletics  Athletics     USA    Men
# ...

# %%
# To get columns info while slicing using left and right bound. again both boundaries inclusive due to loc operator

summer.loc["DRIVAS, Dimitrios":"BLAKE, Arthur", "City": "Discipline"]
# Out:
#                          City      Sport Discipline
# Athlete
# DRIVAS, Dimitrios      Athens   Aquatics   Swimming
# MALOKINIS, Ioannis     Athens   Aquatics   Swimming
# CHASAPIS, Spiridon     Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# HAJOS, Alfred          Athens   Aquatics   Swimming
# ANDREOU, Joannis       Athens   Aquatics   Swimming
# CHOROPHAS, Efstathios  Athens   Aquatics   Swimming
# NEUMANN, Paul          Athens   Aquatics   Swimming
# PEPANOS, Antonios      Athens   Aquatics   Swimming
# LANE, Francis          Athens  Athletics  Athletics
# SZOKOLYI, Alajos       Athens  Athletics  Athletics
# BURKE, Thomas          Athens  Athletics  Athletics
# HOFMANN, Fritz         Athens  Athletics  Athletics
# CURTIS, Thomas         Athens  Athletics  Athletics
# GOULDING, Grantley     Athens  Athletics  Athletics
# LERMUSIAUX, Albin      Athens  Athletics  Athletics
# FLACK, Edwin           Athens  Athletics  Athletics
# ...

# %%
# Try to display information using labels that does not exist in the dataframe

summer.loc[["PHELPS, Michael", "DUCK, Donald"]] # Using a list to pass 2 row labels
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-104-c1ffe8130a61> in <module>
#       1 # Try to display information using labels that does not exist in the dataframe
#       2
# ----> 3 summer.loc[["PHELPS, Michael", "DUCK, Donald"]] # Using a list to pass 2 row labels
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1097                     raise ValueError("Cannot index with multidimensional key")
#    1098
# -> 1099                 return self._getitem_iterable(key, axis=axis)
#    1100
# ...

# %% [markdown]
# ---
#
# Note:
#
#  - The above feature is no longer supported in Pandas new versions
#  - In older versions it was supported, so that Pandas will display the information of valid row labels and discard invalid row labels.
#
#  ---

# %%
# Same principle applies for missing column labels

summer.loc["PHELPS, Michael", ["Year", "Age"]]  # Age column is not available in the dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-103-b146856183cd> in <module>
#       1 # Same principle applies for missing column labels
#       2
# ----> 3 summer.loc["PHELPS, Michael", ["Year", "Age"]]  # Age column is not available in the dataframe
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
# ...

# %% [markdown]
# ---
# ---
# ---
#
# ### Indexing and Slicing with reindex() method

# %% [markdown]
#  - Reindex is frequently used when working with time series data where we have a so called date time index.
#  - But we can use reindex() method for other purposes as well.
#  - One advantage of reindex() method is that we can pass the row labels or column labels to reindex that are not available in the dataframe.
#  - Previously we saw that missing labels doesnot work with .loc operator.

# %%
summer1 = pd.read_csv("summer.csv")

# %%
summer1
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# 5      1896  Athens   Aquatics             Swimming
# 6      1896  Athens   Aquatics             Swimming
# 7      1896  Athens   Aquatics             Swimming
# 8      1896  Athens   Aquatics             Swimming
# 9      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31155  2012  London  Wrestling  Wrestling Freestyle
# 31156  2012  London  Wrestling  Wrestling Freestyle
# 31157  2012  London  Wrestling  Wrestling Freestyle
# 31158  2012  London  Wrestling  Wrestling Freestyle
# 31159  2012  London  Wrestling  Wrestling Freestyle
# 31160  2012  London  Wrestling  Wrestling Freestyle
# ...

# %%
# With .loc operator we can also use range index along with label index
# But we should not mix range index and labelled index

summer1.loc[[0, 5, 30000], ["Athlete", "Medal"]]
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze

# %%
# Using reindex method to work with missing row index, in this case it is a range index
# So we will get an additional 40000 indexed row with NaN values

summer1.reindex(index=[0, 5, 30000, 40000], columns = ["Athlete", "Medal"])
# Out:
#                      Athlete   Medal
# 0              HAJOS, Alfred    Gold
# 5      CHOROPHAS, Efstathios  Bronze
# 30000       PAUTARAN, Maryna  Bronze
# 40000                    NaN     NaN

# %%
# We can also add another column label that is missing from the dataframe

summer1.reindex(index=[0, 5, 30000, 40000], columns = ["Athlete", "Medal", "Age"]) # Age column is extra
# Out:
#                      Athlete   Medal  Age
# 0              HAJOS, Alfred    Gold  NaN
# 5      CHOROPHAS, Efstathios  Bronze  NaN
# 30000       PAUTARAN, Maryna  Bronze  NaN
# 40000                    NaN     NaN  NaN

# %% [markdown]
#  - Reindex method gives us some flexibility but there are also limitations.
#  - Reindex method doesn't work in case we do not have unique column index or row index.
#  - reindex() method always take the argument values as a list, even if it's only one element.

# %%
summer2 = pd.read_csv("summer.csv", index_col="Athlete")

# %%
summer2
# Out:
#                               Year    City      Sport           Discipline  \
# Athlete
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# HERSCHMANN, Otto              1896  Athens   Aquatics             Swimming
# DRIVAS, Dimitrios             1896  Athens   Aquatics             Swimming
# MALOKINIS, Ioannis            1896  Athens   Aquatics             Swimming
# CHASAPIS, Spiridon            1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# HAJOS, Alfred                 1896  Athens   Aquatics             Swimming
# ANDREOU, Joannis              1896  Athens   Aquatics             Swimming
# CHOROPHAS, Efstathios         1896  Athens   Aquatics             Swimming
# NEUMANN, Paul                 1896  Athens   Aquatics             Swimming
# ...                            ...     ...        ...                  ...
# ...

# %%
summer2.reindex(index=["PHELPS, Michael"], columns=["Medal", "Age"]) # Here row index is having duplicate entries
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-118f82bafeb4> in <module>
# ----> 1 summer2.reindex(index=["PHELPS, Michael"], columns=["Medal", "Age"]) # Here row index is having duplicate entries
#
# D:\Programs\Anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     307         @wraps(func)
#     308         def wrapper(*args, **kwargs) -> Callable[..., Any]:
# --> 309             return func(*args, **kwargs)
#     310
#     311         kind = inspect.Parameter.POSITIONAL_OR_KEYWORD
#
# D:\Programs\Anaconda\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    4030         kwargs.pop("axis", None)
#    4031         kwargs.pop("labels", None)
# -> 4032         return super().reindex(**kwargs)
#    4033
#    4034     def drop(
#
# ...

# %% [markdown]
# # TEST LINE - TO BE DELETED LATER
